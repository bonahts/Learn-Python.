# %%
import pandas as pd
import seaborn as sns 
import matplotlib
import numpy as np

# %%
coffee_df = pd.read_csv('C:/Users/bona/Coffee-modified.csv')
coffee_df
# Out:
#         ID  Species                       Owner Country.of.Origin  \
# 0        1  Arabica                   metad plc          Ethiopia
# 1        2  Arabica                   metad plc          Ethiopia
# 2        3  Arabica    grounds for health admin         Guatemala
# 3        4  Arabica         yidnekachew dabessa          Ethiopia
# 4        5  Arabica                   metad plc          Ethiopia
# ...    ...      ...                         ...               ...
# 1314  1307  Arabica    juan carlos garcia lopez            Mexico
# 1315  1308  Arabica     myriam kaplan-pasternak             Haiti
# 1316  1309  Arabica  exportadora atlantic, s.a.         Nicaragua
# 1317  1310  Arabica   juan luis alvarado romero         Guatemala
# 1318  1312  Arabica             bismarck castro          Honduras
#
#                                      Farm.Name                  Lot.Number  \
# 0                                    metad plc                         NaN
# ...

# %%
coffee_df.head()
# Out:
#   ID  Species                     Owner Country.of.Origin  \
# 0  1  Arabica                 metad plc          Ethiopia
# 1  2  Arabica                 metad plc          Ethiopia
# 2  3  Arabica  grounds for health admin         Guatemala
# 3  4  Arabica       yidnekachew dabessa          Ethiopia
# 4  5  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# ...

# %% [markdown]
# #### Untuk menampilkan 5 tabel pertama yang terdapat pada data

# %%
coffee_df.shape
# Out:
# (1319, 44)

# %% [markdown]
# #### 1319 adalah baris. 44 adalah kolom

# %%
coffee_df.dtypes
# Out:
# ID                        object
# Species                   object
# Owner                     object
# Country.of.Origin         object
# Farm.Name                 object
# Lot.Number                object
# Mill                      object
# ICO.Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number.of.Bags            object
# Bag.Weight                object
# In.Country.Partner        object
# Harvest.Year              object
# Grading.Date              object
# Owner.1                   object
# Variety                   object
# Processing.Method         object
# Aroma                     object
# Flavor                    object
# Aftertaste                object
# Acidity                   object
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean.Cup                float64
# ...

# %% [markdown]
# #### Untuk mencari  tipe data pada tiap kolom

# %%
coffee_df.columns
# Out:
# Index(['ID', 'Species', 'Owner', 'Country.of.Origin', 'Farm.Name',
#        'Lot.Number', 'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region',
#        'Producer', 'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner',
#        'Harvest.Year', 'Grading.Date', 'Owner.1', 'Variety',
#        'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste', 'Acidity', 'Body',
#        'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness', 'Cupper.Points',
#        'Total.Cup.Points', 'Moisture', 'Category.One.Defects', 'Quakers',
#        'Color', 'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %% [markdown]
# #### menampilkan nama kolom yang terdapat di dataframe

# %%
coffee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 44 columns):
# ID                       1312 non-null object
# Species                  1319 non-null object
# Owner                    1310 non-null object
# Country.of.Origin        1316 non-null object
# Farm.Name                961 non-null object
# Lot.Number               276 non-null object
# Mill                     1007 non-null object
# ICO.Number               1169 non-null object
# Company                  1105 non-null object
# Altitude                 1092 non-null object
# Region                   1257 non-null object
# Producer                 1084 non-null object
# Number.of.Bags           1314 non-null object
# Bag.Weight               1314 non-null object
# In.Country.Partner       1314 non-null object
# Harvest.Year             1266 non-null object
# Grading.Date             1313 non-null object
# Owner.1                  1305 non-null object
# ...

# %% [markdown]
# #### mencari info tentang data frame

# %%
# true artinya tidak ada nilai kosong pada dataframe 
coffee_df.isnull().values.any()
# coffee_df.isna().values.any()
# Out:
# True

# %% [markdown]
# #### menampilkan apakah terdapat nilai kosong pada dataframe

# %%
#menampilkan data yang sama pada kolom dataframe
coffee_df[coffee_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Species, Owner, Country.of.Origin, Farm.Name, Lot.Number, Mill, ICO.Number, Company, Altitude, Region, Producer, Number.of.Bags, Bag.Weight, In.Country.Partner, Harvest.Year, Grading.Date, Owner.1, Variety, Processing.Method, Aroma, Flavor, Aftertaste, Acidity, Body, Balance, Uniformity, Clean.Cup, Sweetness, Cupper.Points, Total.Cup.Points, Moisture, Category.One.Defects, Quakers, Color, Category.Two.Defects, Expiration, Certification.Body, Certification.Address, Certification.Contact, unit_of_measurement, altitude_low_meters, altitude_high_meters, altitude_mean_meters]
# Index: []
#
# [0 rows x 44 columns]

# %% [markdown]
# #### Tidak terdapat kolom yang sama pada dataframe

# %%
coffee_df.drop_duplicates(inplace=True)
coffee_df
# Out:
#         ID  Species                       Owner Country.of.Origin  \
# 0        1  Arabica                   metad plc          Ethiopia
# 1        2  Arabica                   metad plc          Ethiopia
# 2        3  Arabica    grounds for health admin         Guatemala
# 3        4  Arabica         yidnekachew dabessa          Ethiopia
# 4        5  Arabica                   metad plc          Ethiopia
# ...    ...      ...                         ...               ...
# 1314  1307  Arabica    juan carlos garcia lopez            Mexico
# 1315  1308  Arabica     myriam kaplan-pasternak             Haiti
# 1316  1309  Arabica  exportadora atlantic, s.a.         Nicaragua
# 1317  1310  Arabica   juan luis alvarado romero         Guatemala
# 1318  1312  Arabica             bismarck castro          Honduras
#
#                                      Farm.Name                  Lot.Number  \
# 0                                    metad plc                         NaN
# ...

# %% [markdown]
# #### menghapus duplikasi data

# %%
coffee_df.drop(['ID'], axis = 1)
# Out:
#       Species                       Owner Country.of.Origin  \
# 0     Arabica                   metad plc          Ethiopia
# 1     Arabica                   metad plc          Ethiopia
# 2     Arabica    grounds for health admin         Guatemala
# 3     Arabica         yidnekachew dabessa          Ethiopia
# 4     Arabica                   metad plc          Ethiopia
# ...       ...                         ...               ...
# 1314  Arabica    juan carlos garcia lopez            Mexico
# 1315  Arabica     myriam kaplan-pasternak             Haiti
# 1316  Arabica  exportadora atlantic, s.a.         Nicaragua
# 1317  Arabica   juan luis alvarado romero         Guatemala
# 1318  Arabica             bismarck castro          Honduras
#
#                                      Farm.Name                  Lot.Number  \
# 0                                    metad plc                         NaN
# 1                                    metad plc                         NaN
# ...

# %% [markdown]
# #### untuk menghapus kolom ID yang terdapat di dataframe

# %%
# coffee_df.corr()

# %%
# sns.heatmap(data=coffee_df.corr())

# %%
coffee_df['Species']
# Out:
# 0       Arabica
# 1       Arabica
# 2       Arabica
# 3       Arabica
# 4       Arabica
#          ...
# 1314    Arabica
# 1315    Arabica
# 1316    Arabica
# 1317    Arabica
# 1318    Arabica
# Name: Species, Length: 1319, dtype: object

# %% [markdown]
# #### menampilkan data yang terdapat pada kolom "species"

# %%
coffee_df['Species'].value_counts()
# Out:
# Arabica                                      1311
# Typica"                                         2
# 09e3c859cac41901d54f4bd36cce80d19c9272f5"       1
# 2013/2014"                                      1
# unex guatemala, s.a.                            1
# Specialty Coffee Association"                   1
# CQI Taiwan ICP CQI??????                        1
# KlemOrganics"                                   1
# Name: Species, dtype: int64

# %% [markdown]
# #### untuk menghitung nilai jenis kopi yang terdapat pada kolom "species" di dataframe

# %%
coffee_df['Country.of.Origin']
# Out:
# 0        Ethiopia
# 1        Ethiopia
# 2       Guatemala
# 3        Ethiopia
# 4        Ethiopia
#           ...
# 1314       Mexico
# 1315        Haiti
# 1316    Nicaragua
# 1317    Guatemala
# 1318     Honduras
# Name: Country.of.Origin, Length: 1319, dtype: object

# %% [markdown]
# #### menampilkan data negara asal kopi yang terdapat pada kolom "country of origin"

# %%
coffee_df['Country.of.Origin'].value_counts()
# Out:
# Mexico                                      236
# Colombia                                    183
# Guatemala                                   181
# Brazil                                      132
# Taiwan                                       75
# United States (Hawaii)                       73
# Honduras                                     53
# Costa Rica                                   51
# Ethiopia                                     44
# Tanzania, United Republic Of                 40
# Thailand                                     32
# Uganda                                       26
# Nicaragua                                    26
# Kenya                                        25
# El Salvador                                  21
# Indonesia                                    20
# China                                        16
# Malawi                                       11
# Peru                                         10
# Myanmar                                       8
# ...

# %% [markdown]
# #### untuk mengecek negara asal kopi yang terdapat di kolom "country of origin"

# %%
coffee_df['Farm.Name'].value_counts()
# Out:
# various                       47
# rio verde                     23
# several                       20
# finca medina                  15
# fazenda capoeirnha            13
#                               ..
# la chaparral                   1
# santa mariana/ṣo vicente     1
# jia jia coffee ?????           1
# waylead farms                  1
# tlapacoya                      1
# Name: Farm.Name, Length: 555, dtype: int64

# %%
# coffee_df=coffee_df.replace(-1,np.nan)

# %%
# list = ['Species: 32','ID','Farm.Name']
# x = coffee_df.drop(list,axis = 1 )
# x.head()

# # ax = sns.countplot(y,label="Count")       # M = 212, B = 357
# # B, M = y.value_counts()
# # print('Farm.Name: ',B)
# # print('Species : ',M)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-c82a694f696e> in <module>
#       1 list = ['Species: 32','ID','Farm.Name']
# ----> 2 x = coffee_df.drop(list,axis = 1 )
#       3 x.head()
#       4
#       5 # ax = sns.countplot(y,label="Count")       # M = 212, B = 357
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
# ...

# %%
# sns.countplot(data=coffee_df, x='Aroma')
# plt.tight_layout()

# %% [markdown]
# Visualisasi data 'aroma' berdasarkan grafik menggunakan seaborn

# %%
# coffee_df['Species'].value_counts().plot.pie(autopct='%1.1f%%', labels=None, legend=True)
# plt.tight_layout()

# %% [markdown]
# Berdasarkan visualisasi data dapat disimpulkan bahwa kopi jenis arabica

# %%
# coffee_df.plot()
# plt.tight_layout()

# %%
# coffee_df.hist(figsize=(10,10), bins=10)
# plt.tight_layout()

# %%
# coffee_df.boxplot()
# plt.tight_layout()
# #plt.show()

# %%
# import seaborn as sns 
# sns.scatterplot(x='Owner', y='Country.of.Origin', data=coffee_df, hue='sp')
# plt.tight_layout()

# %%
# sns.pairplot(coffee_df, hue='Country.of.Origin', markers='+')
# plt.tight_layout()

# %% [markdown]
# Classification Model With Machine Learning

# %%
# from sklearn.model_selection import train_test_split #membagi dataset menjadi data traing dan data split
# from sklearn.metrics import accuracy_score,confusion_matrix, classification_report #validasi akurasi model
